# %% [markdown]
# Universidad Tecnológica Nacional. Facultad Regional Mendoza.
# Teoría  de los Circuitos 1
#
# # Parte A: Respuesta en régimen permanente:

# %% [markdown]
# Recordemos que cualquier magnitud que varíe armónicamente con el tiempo, puede ser representada por un vector giratorio de velocidad angular constante denominado **fasor**.
#
# La resolución de circuitos a través de funciones senoidales puede resultar engorroso por lo que se buscan métodos que permitan simplificar la tarea.
#
# Si represantamoslas tensiones y corrientes de un circuito como fasores que giran con igual velocidad angular $\omega$, los desfasajes relativos entre ellos se mantendrán en el tiempo, permitiendo realizar cálculos como si ellos estuvieran fijos y con amplitud constante.
#
# Se dice que al trabajar de este modo, se pasa del dominio del tiempo al dominio de la frecuencia.
#
# En este práctico se utilizará el cálculo simbólico para resolver circuitos.
#
# Así por ejemplo: $$ v_g(t) = r . cos (ω t + θ) [V]$$
#
# representa una señal de tensión expresada en el dominio del tiempo. Para pasarla al dominio de la frecuencia:
# $$\bar{V_g} = r (cos θ + j sen θ) [V]$$ siendo esta la **Forma trigonométrica.**
#
#
# Puede expresarse también de las siguientes formas:
#
# **Forma binómica**: $\bar{V_g}=(V_{gx} + j V_{gy}) [V]$
#
# **Forma polar:** $\bar{V_g} = r\angle{θ}[V]$
#
# **Forma exponencial:** $\bar{V_g} = r e^{jθ} [V]$
#
# ***

# %% [markdown]
# **Ejercicio 1:** dado el siguiente circuito:
#
# a) Calcular las reactancias.
#
# b) Calcular la impedancia total y expresarla en forma polar y binómica.
#
# c) Calcular la corriente en forma polar y luego expresarla en función del tiempo.
#
# d) Calcular la tensión en cada elemento en forma polar y luego expresarla en función del tiempo.
#
# c) Graficar las tensiones en función del tiempo.
#
# d) Graficar el diagrama fasorial.

# %%
#
from lcapy import *


ej1=Circuit()

ej1.add("""
V 1 0  {30*sin(2*pi*50*t)}; down, l={$30sin(2\pi50t)$}
R1 1 2 10; right=2
C1 2 3 318.31e-6;down=1.5
L 3 0 63.66e-3; left
""")


ej1.draw()

# %% [markdown]
# Rtas: a) $X_C=10 \Omega$; $X_L=20 \Omega$; b)$Z_T=(10+j10)\Omega=\sqrt{200}\angle{45°}\Omega$; c) $\bar{I}=2,12\angle{-45°}[A]$; $i(t)=2,12\,cos(2.\pi.50Hz.t-\frac{\pi}{2})[A]$; d)$\bar{V}_R=21,2\angle{-45°}[V]$; $\bar{V}_C=21,2\angle{-135°}[V]$; $\bar{V_L}=42,4\angle{45°}[V]$

# %% [markdown]
# **Ejercicio 2:** A una impedancia $Z= (10 + j15)\Omega$ se le aplica una tensión de $v(t) = 141,2\, cos(2000 t + 45°) [V]$.
#
# a) Dibujar el circuito.
#
# b) Calcular la corriente que hay en el circuito expresada en forma polar.
#
# c) Expresar la corriente en como función del tiempo.
#
#
# Rta: b) $\bar{I}=7,83\angle{-11,31°}[A]$, c) $i(t)=7,83\,cos(2000t-11,31°)[A]$

# %% [markdown]
# **Ejercicio 3:** La corriente que circula en un circuito es $\bar{I}=(4 + j12) [A]$ cuando la tensión aplicada es de $V=180 \angle{55^{\circ}}[V]$
#
# a) Determinar la impedancia del circuito y epresarla de manera polar y binómica.
#
# b) Indicar si la reactancia es capacitiva o inductiva. Justifique.
#
# Rta: a) $\bar{Z}=(13,64-j4,06)\Omega=14,23\angle{-16,57°}\Omega$

# %% [markdown]
# **Ejercicio 4 :** En el circuito de la figura $v(t)=100\,cos(5.10^3.t + 45°)$ hallar:
#
# a) Intensidad de corriente total expresada en forma trigonométrica.
#
# b) El valor de las corrientes $\bar{I}_1$ e $\bar{I}_2$ y las caídas de tensión en cada elemento expresando las respuestas en forma binómica.
#
# c) Dos elementos en serie que produzcan la misma corriente $\bar{I_t}$.
#
# d) Dos elementos en paralelo que produzcan la misma corriente $\bar{I_t}$. (ayuda: resolver pensando en admitancias)

# %%
#
from lcapy import *

ej4=Circuit()
ej4.add("""
V _1 0 {100*cos(5e3*t+45)}; down, l={$v(t)$}
W1 _1 _1b; right, i={$i_t$}
L _1b _2 1.73e-3; down ,l={$1.73mHy$}, i={i_1}
R1 _2 _0b 5; down, l={$5\Omega$}
W2 _0b 0; left
W3 _1b _1c; right=1.2
C _1c _3 50e-6; down, i={$i_2$}
R2 _3 _0c 3; down, l={$3\Omega$}
W4 _0c _0b; left
""")

ej4.draw()

# %% [markdown]
# Rta: a) $\bar{I}_t=(6,84+j17,21)[A]$ b) $\bar{I}_1=(9,67-j2,59)[A]$; $\bar{I}_2=(-2,82-j19,8)[A]$; c) $R=4,96\Omega$ $C=93,55\mu F$ d) $R=5.88\Omega$ $C=14.67\mu F$

# %%
#
from lcapy import *
import cmath
Z1=5+j*5000*0.00173
Z2=3-j*(1/(5000*50e-6))
Zt=Z1*Z2/(Z1+Z2)
V=70.71067812+j*70.71067812
I=(V/Zt).simplify()
I1=(V/Z1).simplify()
I2=(V/Z2).simplify()
I.simplify()
(cmath.phase(V)*180/pi).evalf().simplify()
Zt.simplify()

Y=(1/Zt).simplify()

# %% [markdown]
# **Ejercicio 5:** Dado el siguiente y siendo $\bar{V_1}=35,36 \angle 0°[V]$ y $\bar{V_2}=35,36 \angle 90°[V]$ circuito, calcular:
#
# a) La impedancia equivalente del circuito.
#
# b) La corriente.
#
# c) La diferencia de potencial en cada elemento.
#
# d) Graficar el diagrama fasorial que muestre la corriente y las tensiones en el circuito.

# %%
#
from lcapy import Circuit

ej5=Circuit()
ej5.add("""
V1 _1 0 {35.36*cos(50*2*pi*t)}; down=0.8, l={V_1}
V2 _2 _1 {35.36*sin(50*2*pi*t)}; down , l={V_2}
R1 _2 _3 10; right=1.2, l={$10\Omega$}
L _3 _4 63.662e-3; right, l={$j20\Omega$}
C _4 _0b 106.103e-6; right , l={$-j30$}
W1 _0b _0c; down
W2 _0c 0; left
""")
ej5.draw()

# %% [markdown]
# Rta: a) $\bar{Z}_{eq}=(10-j10)\Omega$; b) $\bar{I}=3,536j[A]$; c) $\bar{V}_R=35,36j[V]$; $\bar{V}_L=-70,72[V]$; $\bar{V}_C=106,8[V]$

# %%
import cmath

V1=35.36+0j
V2=35.36j
Vt=V1+V2
Zt=10+20j-30j
It=Vt/Zt

# %% [markdown]
# **Ejercicio 6:** Un capacitor de $100 \mu F$ está conectado en serie con una bobina de $5 \Omega$ de resistencia y $0,12 Hy$ de inductancia. El módulo de la corriente que hay en el circuito es de $|\bar{I}|=64,85 [A]$. La corriente está retrasada $49,6°$ con respecto a la tensión suministrada y la frecuencia es de $50 Hz$
#
# a) Calcular el valor r.m.s. de la tensión en la bobina y en el capacitor
#
# b) ¿Cuál es el valor de la tensión de alimentación?
#
# c) Indicar si el circuito se comporta de manera inductiva o capacitiva.

# %%
#
from lcapy import *

ej6=Circuit()
ej6.add("""
V _1 0; down, l={$v(t)$}
R _1 _2 5; right, l={$5\Omega$} 
L _2 _3 0.12; right, l={$0.12Hy$}
C _3 _0b 100e-6; right
W1 _0b _0c;down
W2 _0c 0; left
""")

ej6.draw()

# %% [markdown]
# Rta: $\bar{V}_L=2466,25 \angle{32,85°}[V]$; $\bar{V}_C=2064,18\angle{-139,6°}[V]$; $\bar{V}_G=500\angle{0°}[V]$

# %% [markdown]
# **Ejercicio 7:** Dado el siguiente circuito calcular:
#
# a) La impedancia del circuito.
#
# b) La corriente total
#
# c) La corriente que circula en cada elemento.
#
# d) La tensión entre los nodos A-B y B-C.

# %%
#
from lcapy import *

ej7=Circuit()
ej7.add("""
V1  A 0 {20*cos(t)}; down=1.5, l={${20\, cos(t)}$}
W1 A _A ; right=0.4
W2 _A _A1; up=0.4
R1 _A1 _B 10 ; l={$10 \Omega$}, i={$I_1$}
W3 _B B; down=0.4
W4 B _B1; down=0.3 
L _A2 _B1 20; right , l={$20Hy$}, i={$I_2$}
W5 _A _A2; down=0.3
W6 B _B2; right=0.3

W7 _B2 _B3; up=0.3
R2 _C _B3 20 ; left, l={$20 \Omega$},  i={$I_3$}
W8 _C C; down=0.3
W9 C _C1; down=0.3 
C1 _C1 _B4 50e-3; left , l={$50mF$},  i={$I_4$}
W10 _B4 _B2; up=0.3
W11 C _C2; right=0.4
W12 _C2 _C3; down=1.5
W13 _C3 0; left, i={$i_{total}$}

""")

ej7.draw()

# %% [markdown]
# Rta: a) $Z=18,97\angle{-18,43°}\Omega$; b) $\bar{I}_{total}=(10+j3,33)[A]$; c) $\bar{I}_1=(6,66+j6,66)[A]$; $\bar{I}_2=(3,33-j3,33)[A]$  ;$\bar{I}_3=(6,66-j3,33)[A]$; $\bar{I}_4=(3,33+j6,66)[A]$ d) $\bar{V}_{AB}=(66,67+j66,65)[V]$; $\bar{V}_{BC}=(133,32-j66,67)[V]$

# %% [markdown]
# **Ejercicio 8:** Dado el siguiente circuito, enconrtrar el equivalente de Norton entre los terminales A-B.

# %%
#
from lcapy import *
cej8=Circuit()
cej8.add("""
R1 _1   0  10; down, l={$10\Omega$}
L1 _2  _1 10 ; down, l={$j10\Omega$}
W1 _2  _2b   ; right
V1 _2b _3 {10*cos(t)}; down=1.2, l={$10V/20^\circ$}
R2 _3 _0b 5;down, l={$5\Omega$}
W2 _0b 0; left
C1 _2b A 200e-3 ; right , l={$-j5\Omega$}
V2 B _0b {20*cos(t)};left, l={$20V/0^\circ$}
""")
cej8.draw()

# %% [markdown]
# Rta: $\bar{I}_N=2,43\angle{210,68°}[A]$; $Z_N=5,71\angle{-47,77°}\Omega$

# %% [markdown]
# **Ejercicio 9:** Obtener el quivalente de Thevenin del siguiente circuito entre los terminales A-B. Resolver Alplicando correintes de mallas.

# %%
#
from lcapy import * 

cej9=Circuit()
cej9.add("""
R1 _1  0   1    ; down=  , l={$1\Omega$}
R2 _1  _2  1    ; right=1 , l={$1\Omega$}
V1 _2  _3b 180  ; down=1  , l={$180V/0^\circ$}
R3 _3  _4  1    ; down=1  , l={$1\Omega$}
L1 _4   0  0    ; left=1  , l={$j\Omega$}
R4 _2  _5  1    ; right=1 , l={$1\Omega$}
C1 _5  _6  1    ; right=1 , l={$-j\Omega$}
R5 _6  _4b 1    ; down=2  , l={$1\Omega$}
W1 _4b _4       ; left=2
W2 _1  A        ; up=0.5
W3 _6  B        ; up=0.5
W4 _3b _3       ; down=0.01
""")
cej9.draw()

# %% [markdown]
# Rta: $V_{Th}=20V$ $Z_{Th}=1,22\Omega$

# %% [markdown]
# **Ejercicio 10:** Encontrar el equivalente de Thevenin del siguiente circuito entre los términales A-B.

# %%
#
from lcapy import *
cej10=Circuit()
cej10.add("""
V1 _1 0 55; down, l={$55.8 V/-17.4^\circ$}
R1 _1 _2 5; right=1.5,  l={$5\Omega$}
L1 _2 _0b 5;down,  l={$j5\Omega$}
W1 _0b 0; left
R2 _2 _3 2; right,  l={$2\Omega$}
L2 _3 _4 3; right,  l={$j3\Omega$}
R _4 _0c 6; down,  l={$6\Omega$}
W2 _0c _0b; left
W3 _4 A; right
W4 _0c B; right
""")
cej10.draw()

# %% [markdown]
# Rta: $\bar{V}_{Th}=20\angle{0°}[V]$; $Z_{Th}=(3,32+j1,41)\Omega$

# %% [markdown]
# **Ejercicio 11:** Dado el siguiente circuito, encontrar el equivalente de Thevenin entre los terminales A-B

# %%
#
from lcapy import *

cej11=Circuit()
cej11.add("""
V1  _1  0    120       ; down,      l={$120V/ 0^{\circ}$}
R1  _1  _2   12        ; right=1.5 , l={$12\Omega$}
R2  _2  _0b  60        ; down=2    , l={$60\Omega$},v={$V_s$}
W1  _0b 0              ; left
C1  _2  _3   40        ; right     , l={$-j40\Omega$} 
R3  _3  _4b   120       ; down      , l={$120\Omega$}
E1  _4  _0c  _2 _0b 10 ; down      , l=10 V_{s}
W2  _0c _0b            ; left
W3  _3  A              ; right
W4  _0c B              ; right
W5  _4b _4             ; down=0.1
""") 
cej11.draw()

# %% [markdown]
# Rta: $\bar{V}_{Th}=835,22 \angle{-20,17°}[V]$; $Z_{Th}=(120-j60)\Omega$
